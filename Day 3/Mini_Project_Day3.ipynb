# %% [markdown]
# <a href="https://colab.research.google.com/github/KEERTHANASRI-A-M-0609/keerthanasri-codeboosters-2026/blob/main/Day%203/Mini_Project_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup: Get a Free API Key
#
# 1.Got to: https://openweathermap.org/api
# 2.Signup

# %%
API_KEY = '6478714fc80d6790733d043606116975'
BASE_URL = 'http://api.openweathermap.org/data/2.5/weather'
CITIES = ['Mumbai','Delhi','Bangalore','Chennai','Hyderabad','Kolkata','Pune','Jaipur']
print(f'API configured for {len(CITIES)} cities')
print(f'Cities: {CITIES}')
# Out:
# API configured for 8 cities
# Cities: ['Mumbai', 'Delhi', 'Bangalore', 'Chennai', 'Hyderabad', 'Kolkata', 'Pune', 'Jaipur']

# %%
import requests

# API details
API_KEY = '6478714fc80d6790733d043606116975'

BASE_URL = 'https://api.openweathermap.org/data/2.5/weather'

CITIES = [
    'Mumbai',
    'Bangalore',
    'Chennai',
    'Hyderabad',
    'Kolkata',
    'Pune',
    'Jaipur'
]


# Function to fetch weather data
def fetch_weather(city, API_KEY):

    """
    Fetch current weather data for a given city.
    Returns weather details dictionary or None on failure.
    """

    params = {
        'q': city,
        'appid': API_KEY,
        'units': 'metric'
    }

    try:

        response = requests.get(
            BASE_URL,
            params=params,
            timeout=10
        )

        if response.status_code == 200:

            data = response.json()

            return {
                'city': data['name'],
                'temperature': data['main']['temp'],
                'description': data['weather'][0]['description'],
                'icon': data['weather'][0]['icon'],
                'humidity': data['main']['humidity'],
                'wind_speed': data['wind']['speed'],
                'pressure': data['main']['pressure'],
                'visibility': data.get('visibility', 0),
                'sunrise': data['sys']['sunrise'],
                'sunset': data['sys']['sunset']
            }

        else:

            print(f"Error fetching weather data for {city}")
            print(f"Status code: {response.status_code}")

            return None

    except requests.exceptions.RequestException as e:

        print(f"Request failed: {e}")

        return None


# Call API for all cities
print("Calling Weather API...\n")

weather_records = []

for city in CITIES:

    print(f"Fetching weather for {city}...", end=' ')

    record = fetch_weather(city, API_KEY)

    if record:

        weather_records.append(record)

        print(
            f"{record['temperature']}°C, "
            f"{record['description']}"
        )

    else:

        print("Failed")


# Final Output
print("\nWeather Records:\n")

for record in weather_records:
    print(record)
# Out:
# Calling Weather API...
#
# Fetching weather for Mumbai... 33.99°C, haze
# Fetching weather for Bangalore... 29.9°C, scattered clouds
# Fetching weather for Chennai... 36.17°C, few clouds
# Fetching weather for Hyderabad... 30.23°C, broken clouds
# Fetching weather for Kolkata... Error fetching weather data for Kolkata
# Status code: 401
# Failed
# Fetching weather for Pune... 36.89°C, overcast clouds
# Fetching weather for Jaipur... 41.62°C, haze
#
# Weather Records:
#
# {'city': 'Mumbai', 'temperature': 33.99, 'description': 'haze', 'icon': '50d', 'humidity': 59, 'wind_speed': 6.17, 'pressure': 1009, 'visibility': 7000, 'sunrise': 1779841877, 'sunset': 1779889230}
# {'city': 'Bengaluru', 'temperature': 29.9, 'description': 'scattered clouds', 'icon': '03d', 'humidity': 57, 'wind_speed': 3.6, 'pressure': 1009, 'visibility': 6000, 'sunrise': 1779841358, 'sunset': 1779887466}
# {'city': 'Chennai', 'temperature': 36.17, 'description': 'few clouds', 'icon': '02d', 'humidity': 53, 'wind_speed': 4.12, 'pressure': 1005, 'visibility': 6000, 'sunrise': 1779840705, 'sunset': 1779886835}
# {'city': 'Hyderabad', 'temperature': 30.23, 'description': 'broken clouds', 'icon': '04d', 'humidity': 54, 'wind_speed': 7.72, 'pressure': 1011, 'visibility': 6000, 'sunrise': 1779840700, 'sunset': 1779887706}
# {'city': 'Pune', 'temperature': 36.89, 'description': 'overcast clouds', 'icon': '04d', 'humidity': 27, 'wind_speed': 3.76, 'pressure': 1008, 'visibility': 10000, 'sunrise': 1779841688, 'sunset': 1779888936}
# {'city': 'Jaipur', 'temperature': 41.62, 'description': 'haze', 'icon': '50d', 'humidity': 20, 'wind_speed': 4.63, 'pressure': 1001, 'visibility': 4500, 'sunrise': 1779840263, 'sunset': 1779889419}
